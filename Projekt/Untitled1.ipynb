# %%
# Emissionsdaten als Liste von Dictionaries
emission_data = [{"2000": 7.3015565276, "2001": 7.3445498509, "2002": 7.5910820191, "2003": 7.6661065819,
                  "2004": 7.9264551349, "2005": 8.022971702, "2006": 8.247301388, "2007": 8.3558799857,
                  "2008": 8.4741724795, "2009": 8.4774061324, "2010": 8.3759737748, "2011": 8.4235682823,
                  "2012": 8.7662938718, "2013": 9.291035915, "2014": 9.8128903391, "2015": 10.1173860799,
                  "2016": 10.4965465177, "2017": 10.8414736715, "2018": 10.6853845334, "2019": 10.6693128165,
                  "2020": 10.9580914025, "2021": 11.1264878349, "2022": 11.0597619728}]

# Erstellen eines Pandas DataFrame aus den Emissionsdaten
emission_df = pd.DataFrame(emission_data).T
emission_df.columns = ['Emissions']
emission_df.index.name = 'Year'
emission_df.reset_index(inplace=True)
emission_df['Year'] = emission_df['Year'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       2 emission_data = [{"2000": 7.3015565276, "2001": 7.3445498509, "2002": 7.5910820191, "2003": 7.6661065819,
#       3                   "2004": 7.9264551349, "2005": 8.022971702, "2006": 8.247301388, "2007": 8.3558799857,
#       4                   "2008": 8.4741724795, "2009": 8.4774061324, "2010": 8.3759737748, "2011": 8.4235682823,
#       5                   "2012": 8.7662938718, "2013": 9.291035915, "2014": 9.8128903391, "2015": 10.1173860799,
#       6                   "2016": 10.4965465177, "2017": 10.8414736715, "2018": 10.6853845334, "2019": 10.6693128165,
#       7                   "2020": 10.9580914025, "2021": 11.1264878349, "2022": 11.0597619728}]
#       9 # Erstellen eines Pandas DataFrame aus den Emissionsdaten
# ---> 10 emission_df = pd.DataFrame(emission_data).T
#      11 emission_df.columns = ['Emissions']
#      12 emission_df.index.name = 'Year'
#
# NameError: name 'pd' is not defined
